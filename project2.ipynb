# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file_1 = "Resources/country_profile_variables.csv"
cpv_df = pd.read_csv(csv_file_1)
cpv_df.head()
# Out:
#        country          Region  Surface area (km2)  \
# 0  Afghanistan    SouthernAsia              652864
# 1      Albania  SouthernEurope               28748
# 2      Algeria  NorthernAfrica             2381741
# 3      Andorra  SouthernEurope                 468
# 4       Angola    MiddleAfrica             1246700
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              77                               163.8
# 4                           29784                                23.9
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          102.3
# 4                           96.2
#
# ...

# %%
csv_file_2 = "Resources/height_of_male_and_female_by_country.csv"
hmfc_df = pd.read_csv(csv_file_2)
hmfc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country Name         177 non-null    object
#  1   Male Height in Cm    177 non-null    float64
#  2   Female Height in Cm  177 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.3+ KB

# %%
csv_file_3 = "Resources/world_bmi.csv"
wbmi_df = pd.read_csv(csv_file_3)
wbmi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  177 non-null    object
#  1   Both     177 non-null    float64
#  2   Male     177 non-null    float64
#  3   Female   177 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.7+ KB

# %% [markdown]
# ### Create new data with select columns

# %%
new_cpv_df = cpv_df.drop(['Urban population growth rate (average annual %)', 'Fertility rate, total (live births per woman)', 'Life expectancy at birth (females/males, years)','International migrant stock (000/% of total pop.)', 'Refugees and others of concern to UNHCR (in thousands)','Infant mortality rate (per 1000 live births','Health: Physicians (per 1000 pop.)','Education: Government expenditure (% of GDP)','Education: Primary gross enrol. ratio (f/m per 100 pop.)','Education: Secondary gross enrol. ratio (f/m per 100 pop.)','Education: Tertiary gross enrol. ratio (f/m per 100 pop.)','Seats held by women in national parliaments %','Mobile-cellular subscriptions (per 100 inhabitants)', 'Mobile-cellular subscriptions (per 100 inhabitants).1','Individuals using the Internet (per 100 inhabitants)','Threatened species (number)','Forested area (% of land area)','CO2 emission estimates (million tons/tons per capita)','Energy production, primary (Petajoules)','Energy supply per capita (Gigajoules)','Pop. using improved drinking water (urban/rural, %)','Pop. using improved sanitation facilities (urban/rural, %)','Net Official Development Assist. received (% of GNI)'], axis=1)
new_cpv_df.insert(0, 'id', range(1, 1 + len(new_cpv_df)))
new_cpv_df.head()
# Out:
#    id      country          Region  Surface area (km2)  \
# 0   1  Afghanistan    SouthernAsia              652864
# 1   2      Albania  SouthernEurope               28748
# 2   3      Algeria  NorthernAfrica             2381741
# 3   4      Andorra  SouthernEurope                 468
# 4   5       Angola    MiddleAfrica             1246700
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              77                               163.8
# 4                           29784                                23.9
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          102.3
# 4                           96.2
#
# ...

# %%
hmfc_df.insert(0, 'id', range(1, 1 + len(hmfc_df)))
hmfc_df.head()
# Out:
#    id Country Name  Male Height in Cm  Female Height in Cm
# 0   1  Afghanistan             168.50               156.11
# 1   2      Albania             174.07               162.23
# 2   3      Algeria             175.04               162.35
# 3   4      Andorra             178.84               165.53
# 4   5       Angola             168.46               158.10

# %%
wbmi_df.insert(0, 'id', range(1, 1 + len(wbmi_df)))
wbmi_df.head()
# Out:
#    id        Country  Both  Male  Female
# 0   1   Afghanistan   21.6  21.5    21.8
# 1   2       Albania   26.1  26.6    25.6
# 2   3       Algeria   26.2  25.5    27.0
# 3   4       Andorra   27.5  27.8    27.1
# 4   5        Angola   24.1  23.5    24.6

# %%
pi_merged_df = pd.merge(hmfc_df, wbmi_df, on=["id"])
pi_merged_df.drop(['Country', 'Both'], axis=1, inplace=True)
pi_merged_df.rename(columns={'Male': 'Boddy mass Male (kg/m2)', 'Female': 'Boddy mass Female (kg/m2)'}, inplace=True)
pi_merged_df.head()
# Out:
#    id Country Name  Male Height in Cm  Female Height in Cm  \
# 0   1  Afghanistan             168.50               156.11
# 1   2      Albania             174.07               162.23
# 2   3      Algeria             175.04               162.35
# 3   4      Andorra             178.84               165.53
# 4   5       Angola             168.46               158.10
#
#    Boddy mass Male (kg/m2)  Boddy mass Female (kg/m2)
# 0                     21.5                       21.8
# 1                     26.6                       25.6
# 2                     25.5                       27.0
# 3                     27.8                       27.1
# 4                     23.5                       24.6

# %% [markdown]
# ### Connect to local database

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'test3'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
insp = inspect(engine)

# %% [markdown]
# ### Check for tables

# %%
insp.get_table_names()
# Out:
# ['country_profile_variables', 'physical_indicators']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_cpv_df.to_sql(name='country_profile_variables', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
pi_merged_df.to_sql(name='physical_indicators', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the table name
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from country_profile_variables', con=engine).head()
# Out:
#    id      country          Region  Surface area (km2)  \
# 0   1  Afghanistan    SouthernAsia              652864
# 1   2      Albania  SouthernEurope               28748
# 2   3      Algeria  NorthernAfrica             2381741
# 3   4      Andorra  SouthernEurope                 468
# 4   5       Angola    MiddleAfrica             1246700
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              77                               163.8
# 4                           29784                                23.9
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          102.3
# 4                           96.2
#
# ...

# %%
pd.read_sql_query('select * from physical_indicators', con=engine).head()
# Out:
#    id Country Name  Male Height in Cm  Female Height in Cm  \
# 0   1  Afghanistan             168.50               156.11
# 1   2      Albania             174.07               162.23
# 2   3      Algeria             175.04               162.35
# 3   4      Andorra             178.84               165.53
# 4   5       Angola             168.46               158.10
#
#    Boddy mass Male (kg/m2)  Boddy mass Female (kg/m2)
# 0                     21.5                       21.8
# 1                     26.6                       25.6
# 2                     25.5                       27.0
# 3                     27.8                       27.1
# 4                     23.5                       24.6

# %%
sql_join = r"""SELECT country_profile_variables.id, country_profile_variables."country" , country_profile_variables."Region", country_profile_variables."Surface area (km2)" , country_profile_variables."Population in thousands (2017)", country_profile_variables."Population density (per km2, 2017)", country_profile_variables."Sex ratio (m per 100 f, 2017)" , country_profile_variables."GDP: Gross domestic product (million current US$)",
country_profile_variables."GDP growth rate (annual %, const. 2005 prices)" , country_profile_variables."GDP per capita (current US$)" , country_profile_variables."Economy: Agriculture (% of GVA)", country_profile_variables."Economy: Industry (% of GVA)", country_profile_variables."Economy: Services and other activity (% of GVA)", country_profile_variables."Employment: Agriculture (% of employed)", country_profile_variables."Employment: Industry (% of employed)" ,
country_profile_variables."Employment: Services (% of employed)" , country_profile_variables."Unemployment (% of labour force)", country_profile_variables."Labour force participation (female/male pop. %)", country_profile_variables."Population growth rate (average annual %)" , country_profile_variables."Population age distribution (0-14 / 60+ years, %)", country_profile_variables."Health: Total expenditure (% of GDP)",
physical_indicators.id, physical_indicators."Country Name", physical_indicators."Male Height in Cm", physical_indicators."Female Height in Cm", physical_indicators."Boddy mass Male (kg/m2)", physical_indicators."Boddy mass Female (kg/m2)"
FROM country_profile_variables
JOIN physical_indicators
ON country_profile_variables.id = physical_indicators.id"""

# %%
pd.read_sql_query(sql_join, con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_n/mytfny7j0sn48k76y0zspzsw0000gn/T/ipykernel_59745/307636414.py in <module>
# ----> 1 pd.read_sql_query(sql_join, con=engine).head()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     441         parse_dates=parse_dates,
#     442         chunksize=chunksize,
# --> 443         dtype=dtype,
#     444     )
#     445
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# ...
